# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint
import json
from time import sleep
from datetime import date
import zipfile
import os

# Incorporated citipy to determine city based on latitude and longitude
# pip install citipy
from citipy import citipy

# Output File location
output_folder = "output_data"

# %%
# Open the zip file:
csvpath = os.path.join("..", "source_data", "detail_listings.zip")
zf = zipfile.ZipFile(csvpath);

# zf = zipfile.ZipFile('../source_data/detail_listings.zip') 
df = pd.read_csv(zf.open('detail_listings.csv'), low_memory=False)

rows_in_df = len(df)
print(f'Data set has {rows_in_df} rows')

# Drop unneeded columns:
df = df.drop(columns = [
    "listing_url", 
    "thumbnail_url", 
    "picture_url", 
    "medium_url", 
    "xl_picture_url", 
    "host_url", 
    "host_thumbnail_url", 
    "host_picture_url", 
    "scrape_id",
    "host_listings_count", # There is a host_total_listings_count that is a dupe
    "host_acceptance_rate", # NaN
    "calendar_last_scraped",
    "bed_type",
    "last_scraped",
    "calendar_updated",
    "has_availability",
    "availability_30", 
    "availability_60", 
    "availability_90", 
    "availability_365", 
    "license"
])

df.head(1)
# Out:
# Data set has 23745 rows
#      id      name                                            summary  \
# 0  5065  MAUKA BB  Perfect for your vacation, Staycation or just ...
#
#                                                space  \
# 0  Mauka B & B is 400 square feet studio with a p...
#
#                                          description experiences_offered  \
# 0  Perfect for your vacation, Staycation or just ...                none
#
#                                neighborhood_overview  \
# 0  Neighbors here are friendly but are not really...
#
#                                                notes  \
# 0  Located near by is Kalopa State Park with 100 ...
#
#                                              transit  \
# 0  There  is a bus stop located in Honoka'a town ...
#
#                      access  ... instant_bookable is_business_travel_ready  \
# 0  A BBQ grill is available  ...                f                        f
#
#    cancellation_policy require_guest_profile_picture  \
# 0             moderate                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.45
#
# [1 rows x 85 columns]

# %%
# Group the columns to make analysis easier later
        
print('')
print('----------------------')
print('Property-specific columns:')
print('----------------------')
# These are wildcard search terms:
cols = ["experiences_offered", "street", "city", "state", "zipcode", "market", "country", "property"
    , "location", "accomodate", "room", "guest", "is_business_travel_ready", "instant_bookable", "cancel"]
for col in df.columns: 
    if col in cols:
        print(col) 
        
print('')
print('----------------------')
print('All columns:')
print('----------------------')
for col in df.columns: 
    print(col)
# Out:
# ----------------------
# Property-specific columns:
# ----------------------
# experiences_offered
# street
# city
# state
# zipcode
# market
# country
# instant_bookable
# is_business_travel_ready
#
# ----------------------
# All columns:
# ----------------------
# id
# name
# summary
# space
# description
# experiences_offered
# neighborhood_overview
# notes
# transit
# access
# interaction
# house_rules
# host_id
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_is_superhost
# host_neighbourhood
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# street
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# city
# state
# zipcode
# market
# smart_location
# country_code
# country
# latitude
# longitude
# is_location_exact
# property_type
# room_type
# accommodates
# bathrooms
# bedrooms
# beds
# amenities
# square_feet
# price
# weekly_price
# monthly_price
# security_deposit
# cleaning_fee
# guests_included
# extra_people
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# number_of_reviews
# number_of_reviews_ltm
# first_review
# last_review
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# requires_license
# jurisdiction_names
# instant_bookable
# is_business_travel_ready
# cancellation_policy
# require_guest_profile_picture
# require_guest_phone_verification
# calculated_host_listings_count
# calculated_host_listings_count_entire_homes
# calculated_host_listings_count_private_rooms
# calculated_host_listings_count_shared_rooms
# reviews_per_month

# %%
# Create a dataframe w 1 row for each column in the source:
data_dict = pd.DataFrame(columns = [
    "ColumNumber"
    , "Column"
    , "Group"
    , "Subgroup"
    , "Notes"
])

for column in df:
    data_dict = data_dict.append({
            "Column": column
            , "Group": ""
            , "Subgroup": ""
            , "Notes": ""
        }
        , ignore_index=True
    )

# Make the index the column #
data_dict['ColumNumber'] = data_dict.index
        
# For each column, add context:
for index, row in data_dict.iterrows():
    val = str(row["Column"])
    
    if val == "id":
        data_dict.loc[index, "Notes"] = "Primary Key"
    
    if val.find("host") > -1: # val.startswith("host_"):
        data_dict.loc[index, "Group"] = "Host-related"
    
    if val.find("review") > -1:
        data_dict.loc[index, "Group"] = "Review-related"
        
    if (val.find("rule") > -1) | (val.find("require") > -1):
        data_dict.loc[index, "Group"] = "Requirements-related"
        
    if (val.find("neighbo") > -1):
        data_dict.loc[index, "Group"] = "Neighborhood-related"
        
    if (val.find("nights") > -1):
        data_dict.loc[index, "Group"] = "Booking-related"
        
    # Property specific:
    cols = [
        "property", "room", "guest", "is_business_travel_ready", "instant_bookable", "cancel"
        , "space", "name", "summary", "description", "notes", "transit", "access", "interaction"
        , "property_type", "room_type", "amenities"
    ]
    if any(word in val for word in cols):
        data_dict.loc[index, "Group"] = "Property-related"
        
    # Property - "Location" specific:
    cols = [
        "location", "street", "city", "state", "zipcode", "market", "country"
        , "latitude", "longitude", "is_location_exact"
    ]
    if any(word in val for word in cols):
        data_dict.loc[index, "Group"] = "Property-related"
        data_dict.loc[index, "Subgroup"] = "Location"
        
    # Property - "Interior" specific:
    cols = [
        "bathrooms", "bedrooms", "beds", "square_feet"
    ]
    if any(word in val for word in cols):
        data_dict.loc[index, "Group"] = "Property-related"
        data_dict.loc[index, "Subgroup"] = "Interior"
        
    # Property - "Pricing" specific:
    # Things about price, or that we might associate w price
    cols = [
        "price", "weekly_price", "monthly_price"        
        , "security_deposit", "cleaning_fee"
        , "accomodates", "guests_included", "extra_people"
        , "experiences_offered"
    ]
    if any(word in val for word in cols):
        data_dict.loc[index, "Group"] = "Property-related"
        data_dict.loc[index, "Subgroup"] = "Pricing"
        
    # Had to hard code this one for some reason:
    if val == "accommodates":
        data_dict.loc[index, "Group"] = "Property-related"
        data_dict.loc[index, "Subgroup"] = "Pricing"
        
print(data_dict.groupby(["Group", "Subgroup"])["Column"].count())
print('')
print('Columns without a group:')
data_dict[data_dict["Group"] == ""]

# neighbourhood_group_cleansed == island name
# Out:
# Group                 Subgroup
#                                    1
# Booking-related                    8
# Host-related                      12
# Neighborhood-related               5
# Property-related                  20
#                       Interior     4
#                       Location    13
#                       Pricing      9
# Requirements-related               2
# Review-related                    11
# Name: Column, dtype: int64
#
# Columns without a group:
#    ColumNumber Column Group Subgroup        Notes
# 0            0     id                 Primary Key

# %%
# CLEANUP 

# Drop rows with number_of_reviews = 0
# Get names of indexes for which column number_of_reviews has value 0
# Drop by index:
indexNames = df[df['number_of_reviews'] == 0 ].index
df.drop(indexNames , inplace=True)

# Drop rows with number_of_reviews = NaN
df.dropna(axis=0, subset=('number_of_reviews', ))

# Drop rows with NaN review data
df.dropna(axis=0, subset=(
    'review_scores_rating', 
    'review_scores_accuracy', 
    'review_scores_cleanliness', 
    'review_scores_checkin', 
    'review_scores_communication', 
    'review_scores_location', 
    'review_scores_value'
))

print(f'Remaining rows after cleanup: {len(df)}')
# Out:
# Remaining rows after cleanup: 18291

# %%
# Source data has $ and commas 
# Strip the $ out of the pricing-based columns
data_dict[(data_dict["Group"] == "Property-related") & (data_dict["Subgroup"] == "Pricing")]
# Out:
#     ColumNumber               Column             Group Subgroup Notes
# 5             5  experiences_offered  Property-related  Pricing
# 41           41         accommodates  Property-related  Pricing
# 47           47                price  Property-related  Pricing
# 48           48         weekly_price  Property-related  Pricing
# 49           49        monthly_price  Property-related  Pricing
# 50           50     security_deposit  Property-related  Pricing
# 51           51         cleaning_fee  Property-related  Pricing
# 52           52      guests_included  Property-related  Pricing
# 53           53         extra_people  Property-related  Pricing

# %%
# Strip the $ out of the pricing-based columns
data_dict[(data_dict["Group"] == "Property-related") & (data_dict["Subgroup"] == "Pricing")]

if df["price"].dtype != "float64":
    df["price"] = df["price"].str.replace("$", "")
    df["price"] = df["price"].str.replace(",", "")
    df["price"] = df["price"].astype("float64")

if df["weekly_price"].dtype != "float64":
    df["weekly_price"] = df["weekly_price"].str.replace("$", "")
    df["weekly_price"] = df["weekly_price"].str.replace(",", "")
    df["weekly_price"] = df["weekly_price"].astype("float64")

if df["monthly_price"].dtype != "float64":
    df["monthly_price"] = df["monthly_price"].str.replace("$", "")
    df["monthly_price"] = df["monthly_price"].str.replace(",", "")
    df["monthly_price"] = df["monthly_price"].astype("float64")
    
if df["security_deposit"].dtype != "float64":
    df["security_deposit"] = df["security_deposit"].str.replace("$", "")
    df["security_deposit"] = df["security_deposit"].str.replace(",", "")
    df["security_deposit"] = df["security_deposit"].astype("float64")
    
if df["cleaning_fee"].dtype != "float64":
    df["cleaning_fee"] = df["cleaning_fee"].str.replace("$", "")
    df["cleaning_fee"] = df["cleaning_fee"].str.replace(",", "")
    df["cleaning_fee"] = df["cleaning_fee"].astype("float64")   

if df["extra_people"].dtype != "float64":
    df["extra_people"] = df["extra_people"].str.replace("$", "")
    df["extra_people"] = df["extra_people"].str.replace(",", "")
    df["extra_people"] = df["extra_people"].astype("float64")

# %%
# data_dict[data_dict["Group"] == "Host-related"]
host_group = df.groupby("neighbourhood").agg({
    "number_of_reviews": [
        np.count_nonzero,
        np.mean, 
        np.median, 
        np.var, 
        np.std
    ]
})

host_group.rename(columns={'count_nonzero':'Reviews'})
host_group.head()
# bin on reviews_per_month
# Out:
#                                   number_of_reviews                    \
#                                       count_nonzero       mean median
# neighbourhood
# Aiea                                             14  40.428571    8.0
# Airport                                           3   4.000000    4.0
# Ala Moana/Kakaako                                28  23.214286    8.5
# Aliamanu/Salt Lake/Foster Village                 8  74.875000    9.5
# Central Oahu                                     43  29.302326   17.0
#
#
#                                             var         std
# neighbourhood
# Aiea                                2872.417582   53.594940
# Airport                                9.000000    3.000000
# Ala Moana/Kakaako                   1138.767196   33.745625
# Aliamanu/Salt Lake/Foster Village  17739.267857  133.188843
# Central Oahu                        1214.073090   34.843552

# %%
bins_num_reviews = [10, 20, 50, 100, 200, 300, 350, 400, 450, 500, 550, 600, 100000]

# labels - always one less than the range
group_names_num_reviews = [
    "1-10"
    , "11-20"
    , "21-50"
    , "100-200"
    , "201-250"
    , "251-300"
    , "301-350"
    , "351-400"
    , "401-550"
    , "451-500"
    , "501-550"
    , "551-600"
]

df["Bin_NumReviews"] = pd.cut(
    df["number_of_reviews"], 
    bins = bins_num_reviews, 
    labels = group_names_num_reviews
)

df["Bin_NumReviews"].value_counts()
# Out:
# 11-20      3790
# 1-10       2526
# 21-50      2368
# 100-200    1235
# 201-250     250
# 251-300      32
# 301-350      23
# 351-400      10
# 401-550       6
# 551-600       3
# 451-500       3
# 501-550       1
# Name: Bin_NumReviews, dtype: int64

# %%
print(f'Sum: {df["number_of_reviews"].sum()}')
print(f'Count: {df["number_of_reviews"].count()}')

df.groupby("Bin_NumReviews")["number_of_reviews"].sum()
# Out:
# Sum: 623494
# Count: 18291
# Bin_NumReviews
# 1-10        37991
# 11-20      126389
# 21-50      169320
# 100-200    169224
# 201-250     59598
# 251-300     10221
# 301-350      8452
# 351-400      4217
# 401-550      2864
# 451-500      1561
# 501-550       569
# 551-600      1983
# Name: number_of_reviews, dtype: int64

# %%
df.groupby("Bin_NumReviews").agg({
    "number_of_reviews": [
        np.count_nonzero,
        np.mean, 
        np.median, 
        np.var, 
        np.std
    ]
})
# Out:
#                number_of_reviews
#                    count_nonzero        mean median         var        std
# Bin_NumReviews
# 1-10                        2526   15.039984   15.0    8.161173   2.856777
# 11-20                       3790   33.348021   32.0   74.548947   8.634173
# 21-50                       2368   71.503378   70.0  197.305439  14.046545
# 100-200                     1235  137.023482  131.0  741.095883  27.223076
# 201-250                      250  238.392000  232.0  802.456161  28.327657
# 251-300                       32  319.406250  318.0  176.958669  13.302581
# 301-350                       23  367.478261  366.0  157.988142  12.569333
# 351-400                       10  421.700000  421.5  252.900000  15.902830
# 401-550                        6  477.333333  485.5  246.666667  15.705625
# 451-500                        3  520.333333  518.0   24.333333   4.932883
# 501-550                        1  569.000000  569.0         NaN        NaN
# 551-600                        3  661.000000  669.0  577.000000  24.020824

# %%
# Hypothesis candidates: 
# Neighborhood
#     - Is rating related to price within a neighborhood? 
#     - The highest price properties in a neighboorhood will have lower ratings than the lowest price properties?
#      - Best neighborhoods by rating
#      - Best neighborhoods by price
#      - Listing types by neighborhood
#      - Listing types by price
#      - Listing types by rating
# By island: 
#      - Is one island more expensive than the others?

import seaborn as sns
#sns.boxplot(x="day", y="total_bill", hue="smoker", data=df, palette="Set1")
sns.boxplot(
    x = "neighbourhood_group_cleansed",
    y = "number_of_reviews",
    #hue = "price",
    data = df,
    palette = "Set1"
)

# Bin by island
# data_dict[(data_dict["Group"] == "Property-related") & (data_dict["Subgroup"] == "Pricing")]

# %%
# Hypothesis candidates: 
# Neighborhood
#     - Is rating related to price within a neighborhood? 
#     - The highest price properties in a neighboorhood will have lower ratings than the lowest price properties?
#      - Best neighborhoods by rating
#      - Best neighborhoods by price
#      - Listing types by neighborhood
#      - Listing types by price
#      - Listing types by rating
# By island: 
#      - Is one island more expensive than the others?

import seaborn as sns
#sns.boxplot(x="day", y="total_bill", hue="smoker", data=df, palette="Set1")
sns.boxplot(
    x = "neighbourhood_group_cleansed",
    y = "price",
    data = df,
    palette = "Set1"
)

# Bin by island
# data_dict[(data_dict["Group"] == "Property-related") & (data_dict["Subgroup"] == "Pricing")]

# %%
data_dict[(data_dict["Group"] == "Property-related") & (data_dict["Subgroup"] == "Pricing")]
# Out:
#     ColumNumber               Column             Group Subgroup Notes
# 5             5  experiences_offered  Property-related  Pricing
# 41           41         accommodates  Property-related  Pricing
# 47           47                price  Property-related  Pricing
# 48           48         weekly_price  Property-related  Pricing
# 49           49        monthly_price  Property-related  Pricing
# 50           50     security_deposit  Property-related  Pricing
# 51           51         cleaning_fee  Property-related  Pricing
# 52           52      guests_included  Property-related  Pricing
# 53           53         extra_people  Property-related  Pricing

# %%
# If a host has a hugh number of properties then their ratings are not higher 
#     than hosts with fewer properties
bins = [1, 60, 119, 179, 239, 299]

# labels - always one less than the range
group_names = ["0-59 properties", "60-119 properties", "120-179 properties", "180-239 properties", "240+ properties"]

df["Bin_NumProperties"] = pd.cut(df["host_total_listings_count"], bins, labels=group_names)

# df_analyze = pd.concat([df["host_id"], df["host_total_listings_count"], df["Bin_NumProperties"]]).unique()
df_analyze = df.groupby(["host_id", "host_total_listings_count"])
df_analyze.head()

df.groupby(["host_id", "host_total_listings_count"]).count()
# Hosts that have host_total_listings_count == 0

any_dupe_listings = df.groupby(["host_id"]).agg({
        # number of unique listings
        'host_total_listings_count': "nunique"
    }
)

# Are there any where the listing count is wrong?
#print(len(any_dupe_listings[any_dupe_listings["host_total_listings_count"]]
#any_dupe_listings.filter(lambda x: len(x) > 1)  
any_dupe_listings[any_dupe_listings["host_total_listings_count"] > 1]
print("No - no bad data")
# Out:
# No - no bad data

# %%
# Drop all values outside the normal distribution:
x_values = df["review_scores_cleanliness"]
y_values = df["review_scores_rating"]
plt.scatter(x_values, y_values)

# %%
sns.set(style="white")

x_values = df["review_scores_cleanliness"]
y_values = df["review_scores_rating"]

sns.relplot(
    x="review_scores_cleanliness", 
    y="review_scores_rating", 
    #hue="origin", 
    #size="weight",
    #sizes=(40, 400), 
    #alpha=.5, 
    palette="muted",
    height=6, 
    data=df
)

# %%
sns.regplot(
    x="review_scores_cleanliness", 
    y="review_scores_rating", 
    data=df
);

# %%
# Potential question: Of the six dimensions for ratings (Accuracy, Cleanliness, Checkin, Communication, Location, Value), 
# is one more important than the rest? 
# Example: if a property is a low Cleanliness score, would it be more likely that all other scores 
# are also lower on average?

sns.lmplot(
    x="review_scores_cleanliness", 
    y="review_scores_rating", 
    data=df,
    x_jitter=.05
);

# %%
sns.lmplot(
    x="review_scores_cleanliness", 
    y="review_scores_rating", 
    data=df,
    x_jitter=.05,
    x_estimator=np.mean
);

# %%
sns.lmplot(
    x="review_scores_value", 
    y="review_scores_rating", 
    data=df,
    x_jitter=.05,
    x_estimator=np.mean
);

# %%
sns.catplot(
    x="review_scores_value", 
    y="review_scores_rating", 
    data=df
);

# %%
sns.catplot(
    x="review_scores_value", 
    y="review_scores_rating", 
    data=df,
    kind="box"
);

# %%
sns.catplot(
    x="review_scores_cleanliness", 
    y="review_scores_rating", 
    data=df,
    kind="box"
);

# %%
sns.catplot(
    x="review_scores_cleanliness", 
    y="review_scores_rating", 
    kind="boxen",
    data = df.sort_values("price")
)

# %%
sns.catplot(
    x="review_scores_cleanliness", 
    y="review_scores_rating", 
    kind="boxen",
    data=df
)

# %%
sns.catplot(
    x="review_scores_cleanliness", 
    y="Bin_NumReviews", 
    kind="violin",
    data=df
)

# %%
sns.catplot(
    x="review_scores_cleanliness", 
    y="review_scores_value", 
    kind="bar",
    data=df
)

# %%
sns.factorplot(
    x="review_scores_cleanliness", 
    y="review_scores_value", 
    col="neighbourhood_group_cleansed",
    data=df, 
    kind="bar"
)

# %%
# calculate spearman's correlation
#coef, p = spearmanr(df["review_scores_cleanliness"], df["review_scores_value"])
#coef, p = scipy.stats.spearmanr(df["review_scores_cleanliness"], df["review_scores_value"])

# %%
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(
    corr, 
    mask=mask, 
    cmap=cmap, 
    vmax=.3, 
    center=0,
    square=True, 
    linewidths=.5, 
    cbar_kws={"shrink": .5}
)

# %%
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(
    corr, 
    mask=mask, 
    cmap=cmap, 
    vmax=.3, 
    center=0,
    square=True, 
    linewidths=.5, 
    cbar_kws={"shrink": .5}
)

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(),
            vmin=-1);

# %%
sns.heatmap(
    df.corr(),
    vmin=-1,
    cmap='coolwarm'
);

# %%
sns.heatmap(
    df.corr(),
    vmin=-1,
    cmap='coolwarm',
);

# %%
sns.heatmap(
    df[["price", "bedrooms", "cleaning_fee", "neighbourhood_group_cleansed"]].corr(),
    vmin=-1,
    vmax=1,
    cmap='coolwarm',
    annot=True
);

# %%
df.loc[:,x]
# Out:
#          host_id  host_since  \
# 0           7257  2009-01-31
# 1           7620  2009-02-09
# 2           7878  2009-02-13
# 3           7878  2009-02-13
# 4           7887  2009-02-14
# 5           7984  2009-02-16
# 7          10768  2009-03-19
# 8          21844  2009-06-16
# 9          21349  2009-06-13
# 10         33179  2009-08-22
# 11         32794  2009-08-20
# 12         51647  2009-11-05
# 13         52931         NaN
# 14         52967  2009-11-10
# 15         52969  2009-11-10
# 16         53489         NaN
# 17         53657  2009-11-12
# 18         54237  2009-11-14
# 19         54543  2009-11-15
# 20         54660  2009-11-16
# 21         54663  2009-11-16
# 22         54663  2009-11-16
# 24         54814  2009-11-16
# 25         53363  2009-11-11
# 26         53363  2009-11-11
# 27         53363  2009-11-11
# 28         12729  2009-04-09
# 29         61673  2009-12-09
# 30         65594  2009-12-25
# 31         71120  2010-01-17
# ...          ...         ...
# 23320  246043597  2019-02-28
# 23322    6932428  2013-06-15
# 23326  177758677  2018-03-11
# 23329    3801752  2012-10-08
# 23330   18716083  2014-07-23
# 23331   35918384  2015-06-15
# 23333  299265137  2019-10-01
# 23344  145080250  2017-08-09
# 23347  308814642  2019-11-11
# 23357   50409116  2015-12-02
# 23362  309029617  2019-11-12
# 23365  283058526  2019-08-05
# 23380  259825296  2019-05-04
# 23402  101726866  2016-10-29
# 23411   12617504  2014-02-26
# 23414   22635145  2014-10-17
# 23436  173327727  2018-02-14
# 23445  305524246  2019-10-30
# 23453   21302839  2014-09-14
# 23469  226000361  2018-11-16
# 23488   15747000  2014-05-20
# 23499    7558126  2013-07-17
# 23524  161887851  2017-12-08
# 23554  177758677  2018-03-11
# 23558  101591695  2016-10-28
# 23569  304920835  2019-10-27
# 23576  157833059  2017-11-07
# 23582  311670041  2019-11-23
# 23656   43793840  2015-09-09
# 23741  298394653  2019-09-27
#
#                                               host_about  host_response_time  \
# 0      HI\r\nWE LIVE HERE IN HONOKAA ON \r\nFARM  JUS...        within a day
# 1      Lea, born and raised on the Island of Hawaii, ...      within an hour
# 2      Kona Hawaii,\r\n \r\n Ed is a Farmer/Designer ...      within an hour
# 3      Kona Hawaii,\r\n \r\n Ed is a Farmer/Designer ...      within an hour
# 4                                                    NaN  within a few hours
# 5      After vacationing on Kaua'i for more than 15 y...      within an hour
# 7      Resident of Kauai for 25 years, orginally from...      within an hour
# 8      We are from the San Francisco Bay Area in Cali...                 NaN
# 9      Our goal as hosts is to provide a comfortable,...      within an hour
# 10     We have lived on the Island of Hawaii since 19...      within an hour
# 11     Physician working and playing for 30 years in ...      within an hour
# 12     Annie and Greg Fry from Encinitas.  We like to...      within an hour
# 13                                                   NaN                 NaN
# 14                                                   NaN  within a few hours
# 15     Lisa is a local girl who's an adventurous trav...  within a few hours
# 16                                                   NaN                 NaN
# 17     As a Native Hawaiian,  we love and call the Bi...      within an hour
# 18     Anne & I are both retired.  I spent 36 years i...  within a few hours
# 19     I have lived on the beautiful Kona coast on th...  within a few hours
# 20     We're a happy couple in Seattle who visits Haw...      within an hour
# 21        Steve and Janelle keep a casual Puna lifest...      within an hour
# 22        Steve and Janelle keep a casual Puna lifest...      within an hour
# 24     I love living in Hawaii and enjoying everythin...      within an hour
# 25     Traveling around the world learning and experi...      within an hour
# 26     Traveling around the world learning and experi...      within an hour
# 27     Traveling around the world learning and experi...      within an hour
# 28     We live and work in paradise. We grow and harv...      within an hour
# 29                                    I love Traveling        within an hour
# 30     We have been  providing our vacation condo as ...  within a few hours
# 31     Live and Work in Hawaii\r\n\r\nWould love to h...      within an hour
# ...                                                  ...                 ...
# 23320       Lani and Howie are Hawaiian, Friendly, Lo...      within an hour
# 23322  We love to serve! The Day Spa is a revolving d...      within an hour
# 23326                                                NaN      within an hour
# 23329  5 Things About Me:\r\n1) I am a DIY-er and lov...      within an hour
# 23330  Single Dad raising a 6 year old boy in Hawaiia...      within an hour
# 23331  I travel often in search of good food and off ...      within an hour
# 23333                                                NaN  within a few hours
# 23344       Chef, tour guide, health and wellness coach.      within an hour
# 23347                                                NaN      within an hour
# 23357  I moved to Maui 3 years ago for work and its P...  within a few hours
# 23362                                     We love Kauai!      within an hour
# 23365                                                NaN      within an hour
# 23380                                                NaN      within an hour
# 23402                                       Adventurous       within an hour
# 23411                                                NaN        within a day
# 23414                                                NaN  within a few hours
# 23436  I would describe my personality as bubbly,  do...      within an hour
# 23445                                                NaN      within an hour
# 23453  Aloha! We are a fun couple that loves living i...  within a few hours
# 23469                                                NaN      within an hour
# 23488                        Navy Nurse and mother of 3!      within an hour
# 23499  President of Ali'i Architects, LLC\r\nDesigner...  within a few hours
# 23524                                                NaN  within a few hours
# 23554                                                NaN      within an hour
# 23558  Aloha,\r\nI love  the island of Kauai. As an a...      within an hour
# 23569                                                NaN      within an hour
# 23576                                                NaN      within an hour
# 23582  Laid-back retired veteran and now enjoying the...      within an hour
# 23656                                 Real Estate Broker      within an hour
# 23741                                                NaN                 NaN
#
#       host_response_rate host_is_superhost  host_total_listings_count  \
# 0                   100%                 f                        2.0
# 1                   100%                 f                        5.0
# 2                   100%                 f                        3.0
# 3                   100%                 f                        3.0
# 4                   100%                 f                        2.0
# 5                   100%                 t                        2.0
# 7                   100%                 t                        4.0
# 8                    NaN                 f                        1.0
# 9                   100%                 f                        1.0
# 10                  100%                 f                        1.0
# 11                  100%                 f                        1.0
# 12                  100%                 f                        2.0
# 13                   NaN               NaN                        NaN
# 14                   60%                 f                        2.0
# 15                   94%                 t                        2.0
# 16                   NaN               NaN                        NaN
# 17                  100%                 t                        2.0
# 18                  100%                 t                        2.0
# 19                  100%                 f                        2.0
# 20                  100%                 t                       13.0
# 21                   97%                 f                        6.0
# 22                   97%                 f                        6.0
# 24                  100%                 f                        1.0
# 25                  100%                 t                        5.0
# 26                  100%                 t                        5.0
# 27                  100%                 t                        5.0
# 28                  100%                 f                        3.0
# 29                  100%                 f                        2.0
# 30                  100%                 t                        1.0
# 31                  100%                 t                        5.0
# ...                  ...               ...                        ...
# 23320               100%                 f                       22.0
# 23322               100%                 f                        2.0
# 23326                99%                 t                        5.0
# 23329                97%                 t                        2.0
# 23330               100%                 f                        3.0
# 23331                98%                 f                        5.0
# 23333                97%                 f                        0.0
# 23344                92%                 f                        2.0
# 23347               100%                 f                        0.0
# 23357               100%                 f                        1.0
# 23362               100%                 f                        0.0
# 23365                98%                 f                        2.0
# 23380               100%                 f                        0.0
# 23402                93%                 f                        1.0
# 23411                50%                 f                        0.0
# 23414               100%                 t                      123.0
# 23436               100%                 t                        4.0
# 23445               100%                 f                        2.0
# 23453               100%                 t                       21.0
# 23469               100%                 t                        1.0
# 23488               100%                 f                        0.0
# 23499               100%                 t                        6.0
# 23524                96%                 t                        5.0
# 23554                99%                 t                        5.0
# 23558               100%                 f                        6.0
# 23569               100%                 f                        0.0
# 23576               100%                 t                        3.0
# 23582               100%                 f                        1.0
# 23656               100%                 f                      105.0
# 23741                NaN                 f                        0.0
#
#                                       host_verifications host_has_profile_pic  \
# 0      ['email', 'phone', 'reviews', 'offline_governm...                    t
# 1       ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2                   ['email', 'phone', 'reviews', 'kba']                    t
# 3                   ['email', 'phone', 'reviews', 'kba']                    t
# 4      ['email', 'phone', 'reviews', 'offline_governm...                    t
# 5      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 7                          ['email', 'phone', 'reviews']                    t
# 8                   ['email', 'phone', 'reviews', 'kba']                    t
# 9      ['email', 'phone', 'facebook', 'reviews', 'kba...                    t
# 10        ['email', 'phone', 'google', 'reviews', 'kba']                    t
# 11     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 12                  ['email', 'phone', 'reviews', 'kba']                    t
# 13                                                  None                  NaN
# 14      ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 15                  ['email', 'phone', 'reviews', 'kba']                    t
# 16                                                  None                  NaN
# 17     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 18                         ['email', 'phone', 'reviews']                    t
# 19             ['email', 'phone', 'facebook', 'reviews']                    t
# 20                         ['email', 'phone', 'reviews']                    t
# 21     ['email', 'phone', 'reviews', 'offline_governm...                    t
# 22     ['email', 'phone', 'reviews', 'offline_governm...                    t
# 24     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 25     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 26     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 27     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 28      ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 29     ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 30        ['email', 'phone', 'google', 'reviews', 'kba']                    t
# 31      ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# ...                                                  ...                  ...
# 23320  ['email', 'phone', 'offline_government_id', 's...                    t
# 23322  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 23326  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 23329  ['email', 'phone', 'reviews', 'kba', 'work_ema...                    t
# 23330  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 23331  ['email', 'phone', 'google', 'reviews', 'jumio...                    t
# 23333                                 ['email', 'phone']                    t
# 23344  ['email', 'phone', 'jumio', 'offline_governmen...                    t
# 23347  ['phone', 'offline_government_id', 'government...                    t
# 23357               ['email', 'phone', 'reviews', 'kba']                    t
# 23362  ['email', 'phone', 'offline_government_id', 's...                    t
# 23365  ['email', 'phone', 'offline_government_id', 'g...                    t
# 23380  ['phone', 'offline_government_id', 'selfie', '...                    t
# 23402  ['email', 'phone', 'facebook', 'google', 'revi...                    t
# 23411                                 ['email', 'phone']                    t
# 23414                      ['email', 'phone', 'reviews']                    t
# 23436  ['email', 'phone', 'offline_government_id', 's...                    t
# 23445  ['email', 'phone', 'offline_government_id', 's...                    t
# 23453  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 23469                                 ['email', 'phone']                    t
# 23488  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 23499  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 23524                                 ['email', 'phone']                    t
# 23554  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 23558  ['email', 'phone', 'google', 'reviews', 'offli...                    t
# 23569                                 ['email', 'phone']                    t
# 23576  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 23582  ['email', 'phone', 'offline_government_id', 'g...                    t
# 23656               ['email', 'phone', 'reviews', 'kba']                    t
# 23741  ['email', 'phone', 'offline_government_id', 'g...                    t
#
#       host_identity_verified  calculated_host_listings_count  \
# 0                          f                               2
# 1                          f                               5
# 2                          t                               3
# 3                          t                               3
# 4                          f                               1
# 5                          f                               2
# 7                          f                               4
# 8                          t                               1
# 9                          t                               1
# 10                         t                               1
# 11                         f                               1
# 12                         t                               2
# 13                       NaN                              12
# 14                         t                               1
# 15                         t                               2
# 16                       NaN                               7
# 17                         t                               2
# 18                         f                               1
# 19                         f                               2
# 20                         f                              10
# 21                         t                               6
# 22                         t                               6
# 24                         t                               1
# 25                         t                               4
# 26                         t                               4
# 27                         t                               4
# 28                         t                               3
# 29                         t                               1
# 30                         f                               1
# 31                         t                               5
# ...                      ...                             ...
# 23320                      f                              22
# 23322                      t                               5
# 23326                      t                               4
# 23329                      t                               1
# 23330                      t                               3
# 23331                      f                               5
# 23333                      f                               2
# 23344                      f                               1
# 23347                      f                               1
# 23357                      t                               1
# 23362                      f                               1
# 23365                      f                               1
# 23380                      f                               1
# 23402                      f                               2
# 23411                      f                               1
# 23414                      f                             121
# 23436                      f                               4
# 23445                      f                               2
# 23453                      t                              27
# 23469                      f                               2
# 23488                      f                               2
# 23499                      t                               7
# 23524                      f                               6
# 23554                      t                               4
# 23558                      f                               7
# 23569                      f                               3
# 23576                      f                               3
# 23582                      f                               1
# 23656                      f                             105
# 23741                      f                               3
#
#        calculated_host_listings_count_entire_homes
# 0                                                2
# 1                                                4
# 2                                                3
# 3                                                3
# 4                                                1
# 5                                                2
# 7                                                1
# 8                                                1
# 9                                                1
# 10                                               1
# 11                                               1
# 12                                               2
# 13                                              12
# 14                                               1
# 15                                               2
# 16                                               1
# 17                                               2
# 18                                               1
# 19                                               2
# 20                                               9
# 21                                               6
# 22                                               6
# 24                                               1
# 25                                               4
# 26                                               4
# 27                                               4
# 28                                               3
# 29                                               1
# 30                                               1
# 31                                               5
# ...                                            ...
# 23320                                            2
# 23322                                            2
# 23326                                            4
# 23329                                            1
# 23330                                            2
# 23331                                            5
# 23333                                            2
# 23344                                            0
# 23347                                            1
# 23357                                            1
# 23362                                            1
# 23365                                            1
# 23380                                            1
# 23402                                            2
# 23411                                            1
# 23414                                          121
# 23436                                            1
# 23445                                            2
# 23453                                           27
# 23469                                            2
# 23488                                            2
# 23499                                            6
# 23524                                            6
# 23554                                            4
# 23558                                            7
# 23569                                            1
# 23576                                            0
# 23582                                            0
# 23656                                          105
# 23741                                            3
#
# [18291 rows x 12 columns]

# %%
data_dict
# Out:
#     ColumNumber                                        Column  \
# 0             0                                            id
# 1             1                                          name
# 2             2                                       summary
# 3             3                                         space
# 4             4                                   description
# 5             5                           experiences_offered
# 6             6                         neighborhood_overview
# 7             7                                         notes
# 8             8                                       transit
# 9             9                                        access
# 10           10                                   interaction
# 11           11                                   house_rules
# 12           12                                       host_id
# 13           13                                     host_name
# 14           14                                    host_since
# 15           15                                 host_location
# 16           16                                    host_about
# 17           17                            host_response_time
# 18           18                            host_response_rate
# 19           19                             host_is_superhost
# 20           20                            host_neighbourhood
# 21           21                     host_total_listings_count
# 22           22                            host_verifications
# 23           23                          host_has_profile_pic
# 24           24                        host_identity_verified
# 25           25                                        street
# 26           26                                 neighbourhood
# 27           27                        neighbourhood_cleansed
# 28           28                  neighbourhood_group_cleansed
# 29           29                                          city
# ..          ...                                           ...
# 55           55                                maximum_nights
# 56           56                        minimum_minimum_nights
# 57           57                        maximum_minimum_nights
# 58           58                        minimum_maximum_nights
# 59           59                        maximum_maximum_nights
# 60           60                        minimum_nights_avg_ntm
# 61           61                        maximum_nights_avg_ntm
# 62           62                             number_of_reviews
# 63           63                         number_of_reviews_ltm
# 64           64                                  first_review
# 65           65                                   last_review
# 66           66                          review_scores_rating
# 67           67                        review_scores_accuracy
# 68           68                     review_scores_cleanliness
# 69           69                         review_scores_checkin
# 70           70                   review_scores_communication
# 71           71                        review_scores_location
# 72           72                           review_scores_value
# 73           73                              requires_license
# 74           74                            jurisdiction_names
# 75           75                              instant_bookable
# 76           76                      is_business_travel_ready
# 77           77                           cancellation_policy
# 78           78                 require_guest_profile_picture
# 79           79              require_guest_phone_verification
# 80           80                calculated_host_listings_count
# 81           81   calculated_host_listings_count_entire_homes
# 82           82  calculated_host_listings_count_private_rooms
# 83           83   calculated_host_listings_count_shared_rooms
# 84           84                             reviews_per_month
#
#                    Group  Subgroup        Notes
# 0                                   Primary Key
# 1       Property-related
# 2       Property-related
# 3       Property-related
# 4       Property-related
# 5       Property-related   Pricing
# 6   Neighborhood-related
# 7       Property-related
# 8       Property-related
# 9       Property-related
# 10      Property-related
# 11  Requirements-related
# 12          Host-related
# 13      Property-related
# 14          Host-related
# 15      Property-related  Location
# 16          Host-related
# 17          Host-related
# 18          Host-related
# 19          Host-related
# 20  Neighborhood-related
# 21          Host-related
# 22          Host-related
# 23          Host-related
# 24          Host-related
# 25      Property-related  Location
# 26  Neighborhood-related
# 27  Neighborhood-related
# 28  Neighborhood-related
# 29      Property-related  Location
# ..                   ...       ...          ...
# 55       Booking-related
# 56       Booking-related
# 57       Booking-related
# 58       Booking-related
# 59       Booking-related
# 60       Booking-related
# 61       Booking-related
# 62        Review-related
# 63        Review-related
# 64        Review-related
# 65        Review-related
# 66        Review-related
# 67        Review-related
# 68        Review-related
# 69        Review-related
# 70        Review-related
# 71      Property-related  Location
# 72        Review-related
# 73  Requirements-related
# 74      Property-related
# 75      Property-related
# 76      Property-related
# 77      Property-related
# 78      Property-related
# 79      Property-related
# 80          Host-related
# 81          Host-related
# 82      Property-related
# 83      Property-related
# 84        Review-related
#
# [85 rows x 5 columns]

# %%
df.loc[:,data_dict[data_dict["Group"] == "Host-related"]["Column"]]
# Out:
#          host_id  host_since  \
# 0           7257  2009-01-31
# 1           7620  2009-02-09
# 2           7878  2009-02-13
# 3           7878  2009-02-13
# 4           7887  2009-02-14
# 5           7984  2009-02-16
# 7          10768  2009-03-19
# 8          21844  2009-06-16
# 9          21349  2009-06-13
# 10         33179  2009-08-22
# 11         32794  2009-08-20
# 12         51647  2009-11-05
# 13         52931         NaN
# 14         52967  2009-11-10
# 15         52969  2009-11-10
# 16         53489         NaN
# 17         53657  2009-11-12
# 18         54237  2009-11-14
# 19         54543  2009-11-15
# 20         54660  2009-11-16
# 21         54663  2009-11-16
# 22         54663  2009-11-16
# 24         54814  2009-11-16
# 25         53363  2009-11-11
# 26         53363  2009-11-11
# 27         53363  2009-11-11
# 28         12729  2009-04-09
# 29         61673  2009-12-09
# 30         65594  2009-12-25
# 31         71120  2010-01-17
# ...          ...         ...
# 23320  246043597  2019-02-28
# 23322    6932428  2013-06-15
# 23326  177758677  2018-03-11
# 23329    3801752  2012-10-08
# 23330   18716083  2014-07-23
# 23331   35918384  2015-06-15
# 23333  299265137  2019-10-01
# 23344  145080250  2017-08-09
# 23347  308814642  2019-11-11
# 23357   50409116  2015-12-02
# 23362  309029617  2019-11-12
# 23365  283058526  2019-08-05
# 23380  259825296  2019-05-04
# 23402  101726866  2016-10-29
# 23411   12617504  2014-02-26
# 23414   22635145  2014-10-17
# 23436  173327727  2018-02-14
# 23445  305524246  2019-10-30
# 23453   21302839  2014-09-14
# 23469  226000361  2018-11-16
# 23488   15747000  2014-05-20
# 23499    7558126  2013-07-17
# 23524  161887851  2017-12-08
# 23554  177758677  2018-03-11
# 23558  101591695  2016-10-28
# 23569  304920835  2019-10-27
# 23576  157833059  2017-11-07
# 23582  311670041  2019-11-23
# 23656   43793840  2015-09-09
# 23741  298394653  2019-09-27
#
#                                               host_about  host_response_time  \
# 0      HI\r\nWE LIVE HERE IN HONOKAA ON \r\nFARM  JUS...        within a day
# 1      Lea, born and raised on the Island of Hawaii, ...      within an hour
# 2      Kona Hawaii,\r\n \r\n Ed is a Farmer/Designer ...      within an hour
# 3      Kona Hawaii,\r\n \r\n Ed is a Farmer/Designer ...      within an hour
# 4                                                    NaN  within a few hours
# 5      After vacationing on Kaua'i for more than 15 y...      within an hour
# 7      Resident of Kauai for 25 years, orginally from...      within an hour
# 8      We are from the San Francisco Bay Area in Cali...                 NaN
# 9      Our goal as hosts is to provide a comfortable,...      within an hour
# 10     We have lived on the Island of Hawaii since 19...      within an hour
# 11     Physician working and playing for 30 years in ...      within an hour
# 12     Annie and Greg Fry from Encinitas.  We like to...      within an hour
# 13                                                   NaN                 NaN
# 14                                                   NaN  within a few hours
# 15     Lisa is a local girl who's an adventurous trav...  within a few hours
# 16                                                   NaN                 NaN
# 17     As a Native Hawaiian,  we love and call the Bi...      within an hour
# 18     Anne & I are both retired.  I spent 36 years i...  within a few hours
# 19     I have lived on the beautiful Kona coast on th...  within a few hours
# 20     We're a happy couple in Seattle who visits Haw...      within an hour
# 21        Steve and Janelle keep a casual Puna lifest...      within an hour
# 22        Steve and Janelle keep a casual Puna lifest...      within an hour
# 24     I love living in Hawaii and enjoying everythin...      within an hour
# 25     Traveling around the world learning and experi...      within an hour
# 26     Traveling around the world learning and experi...      within an hour
# 27     Traveling around the world learning and experi...      within an hour
# 28     We live and work in paradise. We grow and harv...      within an hour
# 29                                    I love Traveling        within an hour
# 30     We have been  providing our vacation condo as ...  within a few hours
# 31     Live and Work in Hawaii\r\n\r\nWould love to h...      within an hour
# ...                                                  ...                 ...
# 23320       Lani and Howie are Hawaiian, Friendly, Lo...      within an hour
# 23322  We love to serve! The Day Spa is a revolving d...      within an hour
# 23326                                                NaN      within an hour
# 23329  5 Things About Me:\r\n1) I am a DIY-er and lov...      within an hour
# 23330  Single Dad raising a 6 year old boy in Hawaiia...      within an hour
# 23331  I travel often in search of good food and off ...      within an hour
# 23333                                                NaN  within a few hours
# 23344       Chef, tour guide, health and wellness coach.      within an hour
# 23347                                                NaN      within an hour
# 23357  I moved to Maui 3 years ago for work and its P...  within a few hours
# 23362                                     We love Kauai!      within an hour
# 23365                                                NaN      within an hour
# 23380                                                NaN      within an hour
# 23402                                       Adventurous       within an hour
# 23411                                                NaN        within a day
# 23414                                                NaN  within a few hours
# 23436  I would describe my personality as bubbly,  do...      within an hour
# 23445                                                NaN      within an hour
# 23453  Aloha! We are a fun couple that loves living i...  within a few hours
# 23469                                                NaN      within an hour
# 23488                        Navy Nurse and mother of 3!      within an hour
# 23499  President of Ali'i Architects, LLC\r\nDesigner...  within a few hours
# 23524                                                NaN  within a few hours
# 23554                                                NaN      within an hour
# 23558  Aloha,\r\nI love  the island of Kauai. As an a...      within an hour
# 23569                                                NaN      within an hour
# 23576                                                NaN      within an hour
# 23582  Laid-back retired veteran and now enjoying the...      within an hour
# 23656                                 Real Estate Broker      within an hour
# 23741                                                NaN                 NaN
#
#       host_response_rate host_is_superhost  host_total_listings_count  \
# 0                   100%                 f                        2.0
# 1                   100%                 f                        5.0
# 2                   100%                 f                        3.0
# 3                   100%                 f                        3.0
# 4                   100%                 f                        2.0
# 5                   100%                 t                        2.0
# 7                   100%                 t                        4.0
# 8                    NaN                 f                        1.0
# 9                   100%                 f                        1.0
# 10                  100%                 f                        1.0
# 11                  100%                 f                        1.0
# 12                  100%                 f                        2.0
# 13                   NaN               NaN                        NaN
# 14                   60%                 f                        2.0
# 15                   94%                 t                        2.0
# 16                   NaN               NaN                        NaN
# 17                  100%                 t                        2.0
# 18                  100%                 t                        2.0
# 19                  100%                 f                        2.0
# 20                  100%                 t                       13.0
# 21                   97%                 f                        6.0
# 22                   97%                 f                        6.0
# 24                  100%                 f                        1.0
# 25                  100%                 t                        5.0
# 26                  100%                 t                        5.0
# 27                  100%                 t                        5.0
# 28                  100%                 f                        3.0
# 29                  100%                 f                        2.0
# 30                  100%                 t                        1.0
# 31                  100%                 t                        5.0
# ...                  ...               ...                        ...
# 23320               100%                 f                       22.0
# 23322               100%                 f                        2.0
# 23326                99%                 t                        5.0
# 23329                97%                 t                        2.0
# 23330               100%                 f                        3.0
# 23331                98%                 f                        5.0
# 23333                97%                 f                        0.0
# 23344                92%                 f                        2.0
# 23347               100%                 f                        0.0
# 23357               100%                 f                        1.0
# 23362               100%                 f                        0.0
# 23365                98%                 f                        2.0
# 23380               100%                 f                        0.0
# 23402                93%                 f                        1.0
# 23411                50%                 f                        0.0
# 23414               100%                 t                      123.0
# 23436               100%                 t                        4.0
# 23445               100%                 f                        2.0
# 23453               100%                 t                       21.0
# 23469               100%                 t                        1.0
# 23488               100%                 f                        0.0
# 23499               100%                 t                        6.0
# 23524                96%                 t                        5.0
# 23554                99%                 t                        5.0
# 23558               100%                 f                        6.0
# 23569               100%                 f                        0.0
# 23576               100%                 t                        3.0
# 23582               100%                 f                        1.0
# 23656               100%                 f                      105.0
# 23741                NaN                 f                        0.0
#
#                                       host_verifications host_has_profile_pic  \
# 0      ['email', 'phone', 'reviews', 'offline_governm...                    t
# 1       ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2                   ['email', 'phone', 'reviews', 'kba']                    t
# 3                   ['email', 'phone', 'reviews', 'kba']                    t
# 4      ['email', 'phone', 'reviews', 'offline_governm...                    t
# 5      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 7                          ['email', 'phone', 'reviews']                    t
# 8                   ['email', 'phone', 'reviews', 'kba']                    t
# 9      ['email', 'phone', 'facebook', 'reviews', 'kba...                    t
# 10        ['email', 'phone', 'google', 'reviews', 'kba']                    t
# 11     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 12                  ['email', 'phone', 'reviews', 'kba']                    t
# 13                                                  None                  NaN
# 14      ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 15                  ['email', 'phone', 'reviews', 'kba']                    t
# 16                                                  None                  NaN
# 17     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 18                         ['email', 'phone', 'reviews']                    t
# 19             ['email', 'phone', 'facebook', 'reviews']                    t
# 20                         ['email', 'phone', 'reviews']                    t
# 21     ['email', 'phone', 'reviews', 'offline_governm...                    t
# 22     ['email', 'phone', 'reviews', 'offline_governm...                    t
# 24     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 25     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 26     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 27     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 28      ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 29     ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 30        ['email', 'phone', 'google', 'reviews', 'kba']                    t
# 31      ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# ...                                                  ...                  ...
# 23320  ['email', 'phone', 'offline_government_id', 's...                    t
# 23322  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 23326  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 23329  ['email', 'phone', 'reviews', 'kba', 'work_ema...                    t
# 23330  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 23331  ['email', 'phone', 'google', 'reviews', 'jumio...                    t
# 23333                                 ['email', 'phone']                    t
# 23344  ['email', 'phone', 'jumio', 'offline_governmen...                    t
# 23347  ['phone', 'offline_government_id', 'government...                    t
# 23357               ['email', 'phone', 'reviews', 'kba']                    t
# 23362  ['email', 'phone', 'offline_government_id', 's...                    t
# 23365  ['email', 'phone', 'offline_government_id', 'g...                    t
# 23380  ['phone', 'offline_government_id', 'selfie', '...                    t
# 23402  ['email', 'phone', 'facebook', 'google', 'revi...                    t
# 23411                                 ['email', 'phone']                    t
# 23414                      ['email', 'phone', 'reviews']                    t
# 23436  ['email', 'phone', 'offline_government_id', 's...                    t
# 23445  ['email', 'phone', 'offline_government_id', 's...                    t
# 23453  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 23469                                 ['email', 'phone']                    t
# 23488  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 23499  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 23524                                 ['email', 'phone']                    t
# 23554  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 23558  ['email', 'phone', 'google', 'reviews', 'offli...                    t
# 23569                                 ['email', 'phone']                    t
# 23576  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 23582  ['email', 'phone', 'offline_government_id', 'g...                    t
# 23656               ['email', 'phone', 'reviews', 'kba']                    t
# 23741  ['email', 'phone', 'offline_government_id', 'g...                    t
#
#       host_identity_verified  calculated_host_listings_count  \
# 0                          f                               2
# 1                          f                               5
# 2                          t                               3
# 3                          t                               3
# 4                          f                               1
# 5                          f                               2
# 7                          f                               4
# 8                          t                               1
# 9                          t                               1
# 10                         t                               1
# 11                         f                               1
# 12                         t                               2
# 13                       NaN                              12
# 14                         t                               1
# 15                         t                               2
# 16                       NaN                               7
# 17                         t                               2
# 18                         f                               1
# 19                         f                               2
# 20                         f                              10
# 21                         t                               6
# 22                         t                               6
# 24                         t                               1
# 25                         t                               4
# 26                         t                               4
# 27                         t                               4
# 28                         t                               3
# 29                         t                               1
# 30                         f                               1
# 31                         t                               5
# ...                      ...                             ...
# 23320                      f                              22
# 23322                      t                               5
# 23326                      t                               4
# 23329                      t                               1
# 23330                      t                               3
# 23331                      f                               5
# 23333                      f                               2
# 23344                      f                               1
# 23347                      f                               1
# 23357                      t                               1
# 23362                      f                               1
# 23365                      f                               1
# 23380                      f                               1
# 23402                      f                               2
# 23411                      f                               1
# 23414                      f                             121
# 23436                      f                               4
# 23445                      f                               2
# 23453                      t                              27
# 23469                      f                               2
# 23488                      f                               2
# 23499                      t                               7
# 23524                      f                               6
# 23554                      t                               4
# 23558                      f                               7
# 23569                      f                               3
# 23576                      f                               3
# 23582                      f                               1
# 23656                      f                             105
# 23741                      f                               3
#
#        calculated_host_listings_count_entire_homes
# 0                                                2
# 1                                                4
# 2                                                3
# 3                                                3
# 4                                                1
# 5                                                2
# 7                                                1
# 8                                                1
# 9                                                1
# 10                                               1
# 11                                               1
# 12                                               2
# 13                                              12
# 14                                               1
# 15                                               2
# 16                                               1
# 17                                               2
# 18                                               1
# 19                                               2
# 20                                               9
# 21                                               6
# 22                                               6
# 24                                               1
# 25                                               4
# 26                                               4
# 27                                               4
# 28                                               3
# 29                                               1
# 30                                               1
# 31                                               5
# ...                                            ...
# 23320                                            2
# 23322                                            2
# 23326                                            4
# 23329                                            1
# 23330                                            2
# 23331                                            5
# 23333                                            2
# 23344                                            0
# 23347                                            1
# 23357                                            1
# 23362                                            1
# 23365                                            1
# 23380                                            1
# 23402                                            2
# 23411                                            1
# 23414                                          121
# 23436                                            1
# 23445                                            2
# 23453                                           27
# 23469                                            2
# 23488                                            2
# 23499                                            6
# 23524                                            6
# 23554                                            4
# 23558                                            7
# 23569                                            1
# 23576                                            0
# 23582                                            0
# 23656                                          105
# 23741                                            3
#
# [18291 rows x 12 columns]

# %%
subjective_corr = df.corr()
subjective_corr[np.abs(subjective_corr)<.2] = 0
plt.figure(figsize=(5,5))
sns.heatmap(
    subjective_corr,
    vmin=-1,
    vmax=1,
    cmap='coolwarm',
    annot=False
);

# %%
subjective_corr = df.corr()
subjective_corr[np.abs(subjective_corr)<.2] = 0

mask = np.zeros_like(subjective_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


plt.figure(figsize=(5,5))
sns.heatmap(
    subjective_corr,
    vmin=-1,
    vmax=1,
    cmap='coolwarm',
    annot=False,
    mask=mask
);

# %%
#sns.pairplot(df);
data_dict,head()
